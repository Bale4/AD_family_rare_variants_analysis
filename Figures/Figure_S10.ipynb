# %% [markdown]
# # Figure S10 : QQ plots for pLoF rare-variant aggregate analysis of AD-family and ADSP data with APOE4 adjustment

# %%
plots <- function(file,out){
library('qqman')
data <- read.table(gzfile(file), sep='\t', header=T)
lambda <- median(qchisq(1-data$P,1), na.rm=TRUE)/qchisq(0.5,1)
png(out, width = 5, height = 5, unit='in', res=300)
qq_plot <- qq(data$P, xlim = c(0, 6), ylim = c(0, 30), pch = 18, col = "blue4", cex = 1.5, las = 1)
text(3,18, paste("lambda","=",  signif(lambda, digits = 3)) )
dev.off()
}

# %% [markdown]
# ## **Panel A: AD-family Non-Hispanic Whites of pLOF variants**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/AD_rare_variants/SMMAT/apoe/af0.01/model1_skat/European.pca.projected_AD.SMMAT.snp_stats.gz"
out <- "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_NHW_model1_APOE4.qq.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_NHW_model1_APOE4.qq.png -n
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_NHW_model1_APOE4.qq.png (62.8 KiB):

# %% [markdown]
# ## **Panel B: ADSP Non-Hispanic Whites analysis of pLOF**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/ADSP_2023/smmat/WES/apoe/af0.01/model1_skat/European.pca.projected_outlier_removed_AD.SMMAT.snp_stats.gz"
out <- "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_NHW_model1_APOE4.qq.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_NHW_model1_APOE4.qq.png -n
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_NHW_model1_APOE4.qq.png (64.2 KiB):

# %% [markdown]
# ## **Panel C: AD_family Carribean Hispanics pLOF variants**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/AD_rare_variants/SMMAT/apoe/af0.01/model1_skat/Hispanic.pca.projected_AD.SMMAT.snp_stats.gz"
out <- "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_CH_model1_APOE4.qq.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_CH_model1_APOE4.qq.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_CH_model1_APOE4.qq.png (61.3 KiB):

# %% [markdown]
# ## **Panel D: ADSP Carribean Hispanics analysis of pLOF variants**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/ADSP_2023/smmat/WES/apoe/af0.01/model1_skat/Hispanic.pca.projected_outlier_removed_AD.SMMAT.snp_stats.gz"
out <- "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_CH_model1_APOE4.qq.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_CH_model1_APOE4.qq.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_CH_model1_APOE4.qq.png (63.2 KiB):

# %% [markdown]
# ## **Panel E: AD_family African-Americans analysis of pLOF variants**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/AD_rare_variants/SMMAT/apoe/af0.01/model1_skat/African.pca.projected_AD.SMMAT.snp_stats.gz"
out <- "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_AA_model1_APOE4.qq.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_AA_model1_APOE4.qq.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_AA_model1_APOE4.qq.png (61.8 KiB):

# %% [markdown]
# ## **Panel F: ADSP African-Americans analysis of pLOF variants**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/ADSP_2023/smmat/WES/apoe/af0.01/model1_skat/African.pca.projected_outlier_removed_AD.SMMAT.snp_stats.gz"
out <- "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_AA_model1_APOE4.qq.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_AA_model1_APOE4.qq.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_AA_model1_APOE4.qq.png (63.2 KiB):

# %% [markdown]
# # Generate multi-panel figures

# %%
# Multi-panel figure for all AD-family and ADSP across ancestries meta-analysis

# %%
# Create panel plots
library(patchwork)
library(png)
library(gridExtra)
library(grid)
library(ggplot2)

# %%
# File paths for your  PNG figures
file_paths <- c("~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_NHW_model1_APOE4.qq.png",
                "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_NHW_model1_APOE4.qq.png",
               "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_CH_model1_APOE4.qq.png",
                "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_CH_model1_APOE4.qq.png",
               "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_AA_model1_APOE4.qq.png",
                "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_AA_model1_APOE4.qq.png")

# Create a list to store individual plots
plots <- lapply(seq_along(file_paths), function(i) {
  # Read PNG file and create a ggplot
  ggplot() +
    annotation_custom(rasterGrob(readPNG(file_paths[i]), width = 1, height = 1), xmin=-Inf, xmax=Inf, ymin=-Inf, ymax=Inf) +
    theme_void() +  # Use theme_void to remove axis labels and ticks
    labs(title = letters[i])  # Add labels (A, B, C, etc.)
})

# Combine the individual plots into a single multiple-panel figure
combined_figure_all <- wrap_plots(plots, nrow = 3, ncol = 2)
ggsave("~/project_bst/AD_family_Rare_variants/plots/SKAT_O/per_population_model1_APOE4.qq.png", plot = combined_figure_all)
# Display the combined figure
combined_figure_all
# Out:
# Saving 6.67 x 6.67 in image
# plot without title
