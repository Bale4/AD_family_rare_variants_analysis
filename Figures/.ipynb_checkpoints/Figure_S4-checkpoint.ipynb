# %% [markdown]
# # Supplementary Figure 1 : QQ plots for rare-variant aggregate meta-analysis across different ancestries without APOE4 adjustment

# %%
plots <- function(file,out){
library('qqman')
data <- read.table(gzfile(file), sep='\t', header=T)
lambda <- median(qchisq(1-data$P.value,1), na.rm=TRUE)/qchisq(0.5,1)
png(out, width = 5, height = 5, unit='in', res=300)
qq_plot <- qq(data$P.value, xlim = c(0, 6), ylim = c(0, 20), pch = 18, col = "blue4", cex = 1.5, las = 1)
text(3,18, paste("lambda","=",  signif(lambda, digits = 3)) )
dev.off()
}

# %% [markdown]
# ## **Panel A: Over-all meta-analysis pLOF variants**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/ADSP_2023/AD_ADSP_meta/all_model1_sex_af1.txt"
out <- "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/all_meta_model1_noAPOE4.qq.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/SKAT_O/all_meta_model1_noAPOE4.qq.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/SKAT_O/all_meta_model1_noAPOE4.qq.png (62.5 KiB):

# %% [markdown]
# ## **Panel B: Over-all meta-analysis pLOF and missense variants**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/ADSP_2023/AD_ADSP_meta/all_model3_sex_af1.txt"
out <- "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/all_meta_model2_noAPOE4.qq.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/SKAT_O/all_meta_model2_noAPOE4.qq.png -n
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/SKAT_O/all_meta_model2_noAPOE4.qq.png (63.8 KiB):

# %% [markdown]
# ## **Panel C: AD-family data meta-analysis of pLOF variants**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/AD_rare_variants/SMMAT/noapoe/af0.01/model1_skat/meta.smmat_noAPOE4.txt"
out <- "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_meta_model1_noAPOE4.qq.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_meta_model1_noAPOE4.qq.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_meta_model1_noAPOE4.qq.png (59.4 KiB):

# %% [markdown]
# ## **Panel D: AD-family data meta-analysis of pLOF and missense variants**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/AD_rare_variants/SMMAT/noapoe/af0.01/model3_skat/meta.smmat_noAPOE4.txt"
out <- "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_meta_model2_noAPOE4.qq.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_meta_model2_noAPOE4.qq.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_meta_model2_noAPOE4.qq.png (63.1 KiB):

# %% [markdown]
# ## **Panel E: ADSP data meta-analysis of pLOF variant**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/ADSP_2023/smmat/WES/noapoe/af0.01/model1_skat/meta.smmat_noAPOE4.txt"
out <- "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_meta_model1_noAPOE4.qq.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_meta_model1_noAPOE4.qq.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_meta_model1_noAPOE4.qq.png (60.8 KiB):

# %% [markdown]
# ## **Panel F: ADSP data meta-analysis of pLOF and missense variants**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/ADSP_2023/smmat/WES/noapoe/af0.01/model3_skat/meta.smmat_noAPOE4.txt"
out <- "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_meta_model2_noAPOE4.qq.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_meta_model2_noAPOE4.qq.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_meta_model2_noAPOE4.qq.png (62.4 KiB):

# %% [markdown]
# # Generate multi-panel figures

# %%
# Multi-panel figure for all AD-family and ADSP across ancestries meta-analysis

# %%
# Create panel plots
library(patchwork)
library(png)
library(gridExtra)
library(grid)
library(ggplot2)

# %%
# File paths for your  PNG figures
file_paths <- c("~/project_bst/AD_family_Rare_variants/plots/SKAT_O/all_meta_model1_noAPOE4.qq.png",
                "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/all_meta_model2_noAPOE4.qq.png",
               "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_meta_model1_noAPOE4.qq.png",
                "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/AD_family_meta_model2_noAPOE4.qq.png",
               "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_meta_model1_noAPOE4.qq.png",
                "~/project_bst/AD_family_Rare_variants/plots/SKAT_O/ADSP_meta_model1_noAPOE4.qq.png")

# Create a list to store individual plots
plots <- lapply(seq_along(file_paths), function(i) {
  # Read PNG file and create a ggplot
  ggplot() +
    annotation_custom(rasterGrob(readPNG(file_paths[i]), width = 1, height = 1), xmin=-Inf, xmax=Inf, ymin=-Inf, ymax=Inf) +
    theme_void() +  # Use theme_void to remove axis labels and ticks
    labs(title = letters[i])  # Add labels (A, B, C, etc.)
})

# Combine the individual plots into a single multiple-panel figure
combined_figure_all <- wrap_plots(plots, nrow = 3, ncol = 2)
ggsave("~/project_bst/AD_family_Rare_variants/plots/SKAT_O/across_ancestries_meta_noAPOE4.qq.png", plot = combined_figure_all)
# Display the combined figure
combined_figure_all
# Out:
# Saving 6.67 x 6.67 in image
# plot without title
