# %% [markdown]
# # Figure S16: QQ plots of common variant associations (no APOE4 adjustment)

# %% [markdown]
# Note: For the meta-analysis the p-value column is "P.value"

# %%
plots <- function(file,out){
library('qqman')
data <- read.table(gzfile(file), sep='\t', header=T)
lambda <- median(qchisq(1-data$P.value,1), na.rm=TRUE)/qchisq(0.5,1)
png(out, width = 5, height = 5, unit='in', res=300)
qq_plot <- qq(data$P.value, xlim = c(0, 8), ylim = c(0, 70), pch = 18, col = "blue4", cex = 1.5, las = 1)
text(3,25, paste("lambda","=",  signif(lambda, digits = 3)) )
dev.off()
}

# %% [markdown]
# **Panel A: AD-Family meta-analysis**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/metal/meta.noAPOE4.txt"
out <- "~/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_meta_qq_noAPOE4.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_meta_qq_noAPOE4.png -n
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_meta_qq_noAPOE4.png (65.8 KiB):

# %% [markdown]
# **Panel B: ADSP meta-analysis**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/ADSP_2023/gmmat/noapoe/meta.gmmat_noAPOE4.txt"
out <- "~/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_meta_qq_noAPOE4.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_meta_qq_noAPOE4.png -n
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_meta_qq_noAPOE4.png (65.3 KiB):

# %% [markdown]
# Note: Population specific analysis

# %%
plots <- function(file,out){
library('qqman')
data <- read.table(gzfile(file), sep='\t', header=T)
lambda <- median(qchisq(1-data$PVAL,1), na.rm=TRUE)/qchisq(0.5,1)
png(out, width = 5, height = 5, unit='in', res=300)
qq_plot <- qq(data$PVAL, xlim = c(0, 8), ylim = c(0, 70), pch = 18, col = "blue4", cex = 1.5, las = 1)
text(3,30, paste("lambda","=",  signif(lambda, digits = 3)) )
dev.off()
}

# %% [markdown]
# **Panel C: AD-family Non-Hispanic Whites**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/European/European.pca.projected_AD.GMMAT.snp_stats_original_columns.gz"
out <- "~/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_common_variants_NHW_noAPOE4.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_common_variants_NHW_noAPOE4.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_common_variants_NHW_noAPOE4.png (65.5 KiB):

# %% [markdown]
# **Panel D: ADSP Non-Hispanic Whites**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/ADSP_2023/gmmat/noapoe/European.pca.projected_outlier_removed_AD.GMMAT.snp_stats_original_columns.gz"
out <- "~/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_common_variants_NHW_noAPOE4.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_common_variants_NHW_noAPOE4.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_common_variants_NHW_noAPOE4.png (63.9 KiB):

# %% [markdown]
# **Panel E: AD-family Carribean Hispanics**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/Hispanic/Hispanic.pca.projected_AD.GMMAT.snp_stats_original_columns.gz"
out <- "~/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_common_variants_CH_noAPOE4.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_common_variants_CH_noAPOE4.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_common_variants_CH_noAPOE4.png (64.2 KiB):

# %% [markdown]
# **Panel F: ADSP Carribean Hispanics**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/ADSP_2023/gmmat/noapoe/Hispanic.pca.projected_outlier_removed_AD.GMMAT.snp_stats_original_columns.gz"
out <- "~/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_common_variants_CH_noAPOE4.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_common_variants_CH_noAPOE4.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_common_variants_CH_noAPOE4.png (64.0 KiB):

# %% [markdown]
# **Panel G: AD-family African-Americans**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/African/African.pca.projected_AD.GMMAT.snp_stats_original_columns.gz"
out <- "~/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_common_variants_AA_noAPOE4.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_common_variants_AA_noAPOE4.png
# Out:
# > /home/bst2126/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_common_variants_AA_noAPOE4.png (63.6 KiB):

# %% [markdown]
# **Panel H: ADSP African-Americans**

# %%
file <- "/mnt/mfs/statgen/alzheimers-family/ADSP_2023/gmmat/noapoe/African.pca.projected_outlier_removed_AD.GMMAT.snp_stats_original_columns.gz"
out <- "~/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_common_variants_AA_noAPOE4.png"
plots(file,out)
# Out:
# png
#   2

# %%
# Multi-panel figure for all AD-family and ADSP

# %%
# Create panel plots
library(patchwork)
library(png)
library(gridExtra)
library(grid)
library(ggplot2)

# %%
# File paths for your  PNG figures
file_paths <- c("~/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_meta_qq_noAPOE4.png",
                "~/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_meta_qq_noAPOE4.png",
               "~/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_common_variants_NHW_noAPOE4.png",
                "~/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_common_variants_NHW_noAPOE4.png",
               "~/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_common_variants_CH_noAPOE4.png",
                "~/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_common_variants_CH_noAPOE4.png",
               "~/project_bst/AD_family_Rare_variants/plots/GMMAT/AD_family_common_variants_AA_noAPOE4.png",
                "~/project_bst/AD_family_Rare_variants/plots/GMMAT/ADSP_common_variants_AA_noAPOE4.png")

# Create a list to store individual plots
plots <- lapply(seq_along(file_paths), function(i) {
  # Read PNG file and create a ggplot
  ggplot() +
    annotation_custom(rasterGrob(readPNG(file_paths[i]), width = 1, height = 1), xmin=-Inf, xmax=Inf, ymin=-Inf, ymax=Inf) +
    theme_void() +  # Use theme_void to remove axis labels and ticks
    labs(title = letters[i])  # Add labels (A, B, C, etc.)
})

# Combine the individual plots into a single multiple-panel figure
combined_figure_all <- wrap_plots(plots, nrow = 4, ncol = 2)
ggsave("~/project_bst/AD_family_Rare_variants/plots/GMMAT/qq_noAPOE4.png", plot = combined_figure_all)
# Display the combined figure
combined_figure_all
# Out:
# Saving 6.67 x 6.67 in image
# plot without title
