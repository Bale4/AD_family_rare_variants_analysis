# %% [markdown]
# # GMMAT Analyses for common variants on the updated AD Data
# This notebook documents the population specific GMMAT analyses update done by Yu (https://github.com/gaow/alzheimers-family/blob/master/notebook/20210519_GMMAT_analysis.ipynb) using the updated AD pheno (https://github.com/gaow/alzheimers-family/blob/master/notebook/20221121_AD_pheno_update.ipynb).
#
# Major updates for the pheno data
#
# * Most of missing data for age has been completed
# * missing info for APOE4 updated based on the sequence data
# * controls under 60 years of age excluded
# * For the European samples (n = 15) age values coded as like 999, 8027 were replaced by the correct age
# * unaffected singletons removed
# * PCs recalculated based on the updated pheno
#
# Pheno data
#  > /mnt/mfs/statgen/alzheimers-family/pheno/pheno_updated_20221121/
#
# Geno data: WGS data with jointly called EFIGA and NIALOAD data is available here
#  > /mnt/mfs/statgen/alzheimers-family/normalized_bed/normalized_merged_autosome.*
#
#  QCed gene data used for the analyses for African, European and Hispanic
#
#  > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/geno_qced/geno_qced.$i.*

# %% [markdown]
# # Common Variants analyses

# %% [markdown]
# ## Calculate Kin Matrix

# %% [markdown]
# ### Gnerate genoFile with LD pruning as a temporary file to compute GRM

# %%
ml Singularity
for i in African European Hispanic; do
# unrelated individuals
sos run ~/project2022/notebook/AD/xqtl-pipeline/pipeline/GWAS_QC.ipynb qc \
    --cwd mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship \
    --genoFile /mnt/mfs/statgen/alzheimers-family/AD_common_variants/PCA/normalized_merged_autosome.$i.filtered.bed \
    --remove_samples /mnt/mfs/statgen/alzheimers-family/AD_common_variants/PCA/King/normalized_merged_autosome.$i.filtered.related_id \
    --maf_filter 0.01 \
    --geno_filter 0.1 \
    --mind_filter 0.1 \
    --hwe_filter 5e-08 \
    --name unrelated \
    --container /mnt/mfs/statgen/containers/lmm.sif
# related individuals same set of variants
sos run ~/project2022/notebook/AD/xqtl-pipeline/pipeline/GWAS_QC.ipynb qc:1 \
    --cwd /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship \
    --genoFile /mnt/mfs/statgen/alzheimers-family/AD_common_variants/PCA/normalized_merged_autosome.$i.filtered.bed \
    --keep_samples /mnt/mfs/statgen/alzheimers-family/AD_common_variants/PCA/King/normalized_merged_autosome.$i.filtered.related_id \
    --keep_variants /mnt/mfs/statgen/alzheimers-family/AD_common_variants/geno_qced/normalized_merged_autosome.$i.filtered.unrelated.filtered.bim \
    --maf_filter 0 \
    --geno_filter 0.1 \
    --mind_filter 0.1 \
    --hwe_filter 0 \
    --name related \
    --container /mnt/mfs/statgen/containers/lmm.sif 
done
# Out:
# INFO: Running basic QC filters: Filter SNPs and select individuals
# INFO: basic QC filters is completed.
# INFO: basic QC filters output:   /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.African.filtered.unrelated.filtered.bed
# INFO: Running LD pruning: LD prunning and remove related individuals (both ind of a pair)
# INFO: LD pruning is completed.
# INFO: LD pruning output:   /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.African.filtered.unrelated.filtered.prune.bed /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.African.filtered.unrelated.filtered.prune.in
# INFO: Workflow qc (ID=wa8148975adbd03a6) is executed successfully with 2 completed steps.
# INFO: Running basic QC filters: Filter SNPs and select individuals
# INFO: basic QC filters is completed.
# INFO: basic QC filters output:   /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.African.filtered.related.filtered.extracted.bed
# INFO: Workflow qc (ID=wda57dd636afb9942) is executed successfully with 1 completed step.
# INFO: Running basic QC filters: Filter SNPs and select individuals
# INFO: basic QC filters is completed.
# INFO: basic QC filters output:   /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.European.filtered.unrelated.filtered.bed
# INFO: Running LD pruning: LD prunning and remove related individuals (both ind of a pair)
# INFO: LD pruning is completed.
# INFO: LD pruning output:   /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.European.filtered.unrelated.filtered.prune.bed /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.European.filtered.unrelated.filtered.prune.in
# INFO: Workflow qc (ID=w0f4640ad9cbb209e) is executed successfully with 2 completed steps.
# INFO: Running basic QC filters: Filter SNPs and select individuals
# INFO: basic QC filters is completed.
# INFO: basic QC filters output:   /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.European.filtered.related.filtered.extracted.bed
# INFO: Workflow qc (ID=w5e782c67b9b7c1e1) is executed successfully with 1 completed step.
# INFO: Running basic QC filters: Filter SNPs and select individuals
# INFO: basic QC filters is completed.
# INFO: basic QC filters output:   /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.Hispanic.filtered.unrelated.filtered.bed
# INFO: Running LD pruning: LD prunning and remove related individuals (both ind of a pair)
# INFO: LD pruning is completed.
# INFO: LD pruning output:   /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.Hispanic.filtered.unrelated.filtered.prune.bed /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.Hispanic.filtered.unrelated.filtered.prune.in
# INFO: Workflow qc (ID=w9e510a73b45c09dd) is executed successfully with 2 completed steps.
# INFO: Running basic QC filters: Filter SNPs and select individuals
# INFO: basic QC filters is completed.
# INFO: basic QC filters output:   /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.Hispanic.filtered.related.filtered.extracted.bed
# INFO: Workflow qc (ID=w4a2affcb04362aba) is executed successfully with 1 completed step.

# %%
# merge two data-sets
for i in African European Hispanic; do
    plink --bfile /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.$i.filtered.related.filtered.extracted \
         --bmerge /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.$i.filtered.unrelated.filtered.prune.bed \
                  /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.$i.filtered.unrelated.filtered.prune.bim \
                  /mnt/vast/hpc/csg/bst2126/notebook_Bale/AD_family/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/normalized_merged_autosome.$i.filtered.unrelated.filtered.prune.fam \
        --make-bed --keep-allele-order --out /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/geno_pruned.$i
done

# %%
##in order to run gemma, pheno column in fam file can not be missing, so make modification on fam file.
data=read.table('/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/geno_pruned.African.fam',header=F)
data[,6]=5
write.table(data,'/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/geno_pruned.African.fam',col.names=F,row.names=F,quote=F)

data1=read.table('/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/geno_pruned.European.fam',header=F)
data1[,6]=5
write.table(data1,'/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/geno_pruned.European.fam',col.names=F,row.names=F,quote=F)

data2=read.table('/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/geno_pruned.Hispanic.fam',header=F)
data2[,6]=5
write.table(data2,'/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/geno_pruned.Hispanic.fam',col.names=F,row.names=F,quote=F)

# %% [markdown]
# ### Compute GRM

# %%
ml GEMMA
for i in African European Hispanic; do
gemma \
  -bfile /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/geno_pruned.$i \
  -gk 2 \
  -o geno_pruned_$i \
  -outdir /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship
done
# Out:
# GEMMA 0.98.5 (2021-08-25) by Xiang Zhou, Pjotr Prins and team (C) 2012-2021
# Reading Files ...
# ## number of total individuals = 113
# ## number of analyzed individuals = 113
# ## number of covariates = 1
# ## number of phenotypes = 1
# ## number of total SNPs/var        = 25339986
# ## number of analyzed SNPs         =  2322099
# Calculating Relatedness Matrix ...
# ================================================== 100%
# **** INFO: Done.
# GEMMA 0.98.5 (2021-08-25) by Xiang Zhou, Pjotr Prins and team (C) 2012-2021
# Reading Files ...
# ## number of total individuals = 947
# ## number of analyzed individuals = 947
# ## number of covariates = 1
# ## number of phenotypes = 1
# ## number of total SNPs/var        = 12278121
# ## number of analyzed SNPs         =  1649154
# Calculating Relatedness Matrix ...
# ================================================== 100%
# **** INFO: Done.
# GEMMA 0.98.5 (2021-08-25) by Xiang Zhou, Pjotr Prins and team (C) 2012-2021
# Reading Files ...
# ## number of total individuals = 1836
# ## number of analyzed individuals = 1836
# ## number of covariates = 1
# ## number of phenotypes = 1
# ## number of total SNPs/var        = 17367933
# ## number of analyzed SNPs         =  2630487
# Calculating Relatedness Matrix ...
# ================================================== 100%
# **** INFO: Done.

# %% [markdown]
# ### Null Models

# %%
#MODEL ONE
for i in African European Hispanic; do
module load Singularity
sos run ~/project2022/bioworkflows/GWAS/LMM.ipynb null_model \
--cwd /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/null2 \
--bfile /mnt/mfs/statgen/alzheimers-family/AD_common_variants/geno_qced/geno_qced.$i.fam \
--phenoFile /mnt/mfs/statgen/alzheimers-family/AD_common_variants/PCA/plots/$i.pca.projected.txt \
--grmFile /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/geno_pruned_$i.sXX.txt \
--phenoCol AD \
--container_lmm /mnt/vast/hpc/csg/containers/lmm.sif \
--covarCol SEX \
--qCovarCol AGE PC1 PC2 PC3 \
--model_name noAPOE
done
# Out:
# INFO: Running null_model: fit a GLMM with covariate adjustment and random effects to account for population structure and family or cryptic relatedness
# INFO: null_model is completed.
# INFO: null_model output:   /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/null2/geno_qced.African.African.pca.projected.noAPOE.rds
# INFO: Workflow null_model (ID=w46d288a805b53255) is executed successfully with 1 completed step.
# INFO: Running null_model: fit a GLMM with covariate adjustment and random effects to account for population structure and family or cryptic relatedness
# INFO: null_model is completed.
# INFO: null_model output:   /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/null2/geno_qced.European.European.pca.projected.noAPOE.rds
# INFO: Workflow null_model (ID=w7d9dd3733509db99) is executed successfully with 1 completed step.
# INFO: Running null_model: fit a GLMM with covariate adjustment and random effects to account for population structure and family or cryptic relatedness
# INFO: null_model is completed.
# INFO: null_model output:   /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/null2/geno_qced.Hispanic.Hispanic.pca.projected.noAPOE.rds
# INFO: Workflow null_model (ID=w0476a5ff9a516f22) is executed successfully with 1 completed step.

# %%
#MODEL ONE
for i in African European Hispanic; do
module load Singularity
sos run ~/project2022/bioworkflows/GWAS/LMM.ipynb null_model \
--cwd /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/null2 \
--bfile /mnt/mfs/statgen/alzheimers-family/AD_common_variants/geno_qced/geno_qced.$i.fam \
--phenoFile /mnt/mfs/statgen/alzheimers-family/AD_common_variants/PCA/plots/$i.pca.projected.txt \
--grmFile /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/kinship/geno_pruned_$i.sXX.txt \
--phenoCol AD \
--container_lmm /mnt/vast/hpc/csg/containers/lmm.sif \
--covarCol SEX APOE \
--qCovarCol AGE PC1 PC2 PC3 \
--model_name APOE
done
# Out:
# INFO: Running null_model: fit a GLMM with covariate adjustment and random effects to account for population structure and family or cryptic relatedness
# INFO: null_model is completed.
# INFO: null_model output:   /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/null2/geno_qced.African.African.pca.projected.APOE.rds
# INFO: Workflow null_model (ID=wf8fe48d9825be388) is executed successfully with 1 completed step.
# INFO: Running null_model: fit a GLMM with covariate adjustment and random effects to account for population structure and family or cryptic relatedness
# INFO: null_model is completed.
# INFO: null_model output:   /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/null2/geno_qced.European.European.pca.projected.APOE.rds
# INFO: Workflow null_model (ID=w84f713ef7511311b) is executed successfully with 1 completed step.
# INFO: Running null_model: fit a GLMM with covariate adjustment and random effects to account for population structure and family or cryptic relatedness
# INFO: null_model is completed.
# INFO: null_model output:   /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/null2/geno_qced.Hispanic.Hispanic.pca.projected.APOE.rds
# INFO: Workflow null_model (ID=wd135cb63a683aee0) is executed successfully with 1 completed step.

# %% [markdown]
# # Common Variants

# %% [markdown]
# ## Analyses with SEX and AGE as covariate

# %%
#!/bin/sh
#$ -l h_rt=4:00:00
#$ -l h_vmem=40G
#$ -N gmmat_update_noAPOE4
#$ -o /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4-$JOB_ID.out
#$ -e /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4-$JOB_ID.err  
#$ -j y
#$ -S /bin/bash

export PATH=$HOME/miniconda3/bin:$PATH

module load Singularity/3.5.3

for i in African European Hispanic; do
sos run ~/project2022/bioworkflows/GWAS/LMM.ipynb GMMAT \
--cwd /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/$i \
--bfile /mnt/mfs/statgen/alzheimers-family/AD_common_variants/geno_qced/geno_qced.$i.bed \
--null_model /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/null2/geno_qced.$i.$i.pca.projected.noAPOE.rds \
--phenoFile /mnt/mfs/statgen/alzheimers-family/AD_common_variants/PCA/plots/$i.pca.projected.txt \
--formatFile ~/project2022/bioworkflows/GWAS/data/gmmat_template.yml \
--label_annotate SNP \
--phenoCol AD \
--covarMaxLevels 10 \
--numThreads 20 \
--bgenMinMAF 0.01 \
--container_lmm /mnt/vast/hpc/csg/containers/lmm.sif \
--container_marp /mnt/vast/hpc/csg/containers/marp.sif \
--geno_filter 0.01 \
--nperbatch 100
done

# %% [markdown]
# ## Analyses with APOE and SEX, AGE as covariate

# %%
#!/bin/sh
#$ -l h_rt=23:00:00
#$ -l h_vmem=1000G
#$ -N gmmat_update_APOE4
#$ -o /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4-$JOB_ID.out
#$ -e /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4-$JOB_ID.err  
#$ -j y
#$ -S /bin/bash

export PATH=$HOME/miniconda3/bin:$PATH


module load Singularity/3.5.3

for i in African European Hispanic; do
sos run ~/project2022/bioworkflows/GWAS/LMM.ipynb GMMAT \
--cwd /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/$i \
--bfile /mnt/mfs/statgen/alzheimers-family/AD_common_variants/geno_qced/geno_qced.$i.bed \
--null_model /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/null2/geno_qced.$i.$i.pca.projected.APOE.rds \
--phenoFile /mnt/mfs/statgen/alzheimers-family/AD_common_variants/PCA/plots/$i.pca.projected.txt \
--formatFile ~/project2022/bioworkflows/GWAS/data/gmmat_template.yml \
--label_annotate SNP \
--phenoCol AD \
--covarMaxLevels 10 \
--numThreads 20 \
--bgenMinMAF 0.01 \
--container_lmm /mnt/vast/hpc/csg/containers/lmm.sif \
--container_marp /mnt/vast/hpc/csg/containers/marp.sif \
--geno_filter 0.01 \
--nperbatch 100
done

# %% [markdown]
# ## Manhattan and qq plots

# %% [markdown]
# ### Plots for African population

# %%
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/African/African.pca.projected_AD.GMMAT.qq.png
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/African/African.pca.projected_AD.GMMAT.manhattan.png
# Out:
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/African/African.pca.projected_AD.GMMAT.manhattan.png (206.4 KiB):
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/African/African.pca.projected_AD.GMMAT.qq.png (79.1 KiB):

# %%
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/African/African.pca.projected_AD.GMMAT.qq.png
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/African/African.pca.projected_AD.GMMAT.manhattan.png
# Out:
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/African/African.pca.projected_AD.GMMAT.manhattan.png (205.3 KiB):
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/African/African.pca.projected_AD.GMMAT.qq.png (79.1 KiB):

# %% [markdown]
# ### Plots for European population

# %%
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/European/European.pca.projected_AD.GMMAT.qq.png
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/European/European.pca.projected_AD.GMMAT.manhattan.png
# Out:
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/European/European.pca.projected_AD.GMMAT.manhattan.png (92.2 KiB):
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/European/European.pca.projected_AD.GMMAT.qq.png (72.6 KiB):

# %%
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/European/European.pca.projected_AD.GMMAT.qq.png
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/European/European.pca.projected_AD.GMMAT.manhattan.png
# Out:
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/European/European.pca.projected_AD.GMMAT.manhattan.png (200.9 KiB):
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/European/European.pca.projected_AD.GMMAT.qq.png (79.7 KiB):

# %%
#annotation from Badri
annotation <- read.table('~/project_bst/AD_family_design/EFIGA_NIALOAD_ROSMAP/GMMAT2_20220802/annotation2.txt',header = T)
#attach annotated genes and effects for the significant variants
EUR_noapoe_sig_annotation <- merge(EUR_noapoe,annotation,by.x = 'SNP',by.y = 'SNP1',all.x = T)
write.csv(EUR_noapoe_sig_annotation,'EUR_noapoe.csv')

# %% [markdown]
# ### Plots for Hispanic population

# %%
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/Hispanic/Hispanic.pca.projected_AD.GMMAT.qq.png
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/Hispanic/Hispanic.pca.projected_AD.GMMAT.manhattan.png
# Out:
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/Hispanic/Hispanic.pca.projected_AD.GMMAT.manhattan.png (196.0 KiB):
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/Hispanic/Hispanic.pca.projected_AD.GMMAT.qq.png (79.1 KiB):

# %%
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/Hispanic/Hispanic.pca.projected_AD.GMMAT.qq.png
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/Hispanic/Hispanic.pca.projected_AD.GMMAT.manhattan.png
# Out:
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/Hispanic/Hispanic.pca.projected_AD.GMMAT.manhattan.png (197.8 KiB):
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/Hispanic/Hispanic.pca.projected_AD.GMMAT.qq.png (79.2 KiB):

# %% [markdown]
# ## meta analysis

# %% [markdown]
# ### with out APOE4

# %%
SCHEME STDERR
MARKER   SNP
WEIGHT   N
ALLELE   A2 A1
EFFECT   BHAT
STDERR   SBHAT
PVAL     PVAL
FREQLABEL AF
GENOMICCONTROL ON
AVERAGEFREQ ON
MINMAXFREQ ON

PROCESS /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/European/geno_qced.European.European.pca.projected.gmmat.score.txt.gz
PROCESS /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/Hispanic/geno_qced.Hispanic.Hispanic.pca.projected.gmmat.score.txt.gz
PROCESS /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/African/geno_qced.African.African.pca.projected.gmmat.score.txt.gz

OUTFILE /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/metal/AD.GMMAT_noAPOE4_META .TXT
ANALYZE
ANALYZE HETEROGENEITY

# %%
library(stringr) # to replace strings
library(tidyr) # to get  separate function separate the marker name 
library(data.table)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# Reformate the metal result and generat manhattan and qq plots

meta_noAPOE4 <- read.table('/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/metal/AD.GMMAT_noAPOE4_META2.TXT', header = T, sep = '\t')
meta_noAPOE4 <- meta_noAPOE4 %>% mutate (SNP = MarkerName)
meta_noAPOE4 <- meta_noAPOE4 %>% mutate(across('MarkerName', str_replace_all, '_', ':'))
meta_noAPOE4 <- meta_noAPOE4 %>% separate(MarkerName, c('CHR','POS','REF', 'ALT'),  sep = ':')
meta_noAPOE4 <- meta_noAPOE4 %>% mutate(across('CHR', str_replace, 'chr', ''))
meta_noAPOE4$POS <-  as.numeric(meta_noAPOE4$POS)
meta_noAPOE4$CHR <-  as.numeric(meta_noAPOE4$CHR)
write.table(meta_noAPOE4,'/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/metal/meta.noAPOE4.txt', sep = '\t', quote = F, col.names = T, row.names = F)

# %%
library(qqman)
library(ggplot2)
library(gridExtra)
library(grid)
library(png)
# Out:
# For example usage please run: vignette('qqman')
#
#
#
# Citation appreciated but not required:
#
# Turner, (2018). qqman: an R package for visualizing GWAS results using Q-Q and manhattan plots. Journal of Open Source Software, 3(25), 731, https://doi.org/10.21105/joss.00731.
#
#
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
meta_noAPOE4 <- read.table('/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/metal/meta.noAPOE4.txt', header = T, sep = '\t')

### For Manhattan plot using qqman #### 
## manhattan plot
png(filename = "/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/metal/meta_noapoe4_manhattan.plot.png", width = 6, height = 4, unit='in', res=300)
manhattan(meta_noAPOE4, chr='CHR', bp='POS', snp='SNP', p='P.value', main = 'Manhattan plot', cex = 0.6, cex.axis = 0.9, col = c("blue4", "orange3"))
dev.off()
### qq plot
png(filename = "/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/metal/meta_noapoe4_qq.plot.png", width = 5, height = 5, unit='in', res=300)
qq(meta_noAPOE4$P.value, main = "QQ plot ", cex = 1.5,las = 1, cex.axis = 0.9, col = "blue4")
dev.off()
# Out:
# png
#   2
# png
#   2

# %%
# calculate lamda

lambda <- median(qchisq(meta_noAPOE4$P.value, df=1, lower.tail=FALSE)) / qchisq(0.5, 1)

# %%
lambda
# Out:
# [1] 0.9888482

# %%
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/metal/meta_noapoe4_manhattan.plot.png
%preview /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/metal/meta_noapoe4_qq.plot.png
# Out:
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/metal/meta_noapoe4_qq.plot.png (72.7 KiB):
# > /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/noAPOE4/metal/meta_noapoe4_manhattan.plot.png (97.0 KiB):

# %% [markdown]
# ### with APOE4 adjustment

# %%
library(dplyr)

# %%
SCHEME STDERR
MARKER   SNP
WEIGHT   N
ALLELE   A2 A1
EFFECT   BHAT
STDERR   SBHAT
PVAL     PVAL
FREQLABEL AF
GENOMICCONTROL ON
AVERAGEFREQ ON
MINMAXFREQ ON

PROCESS /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/European/geno_qced.European.European.pca.projected.gmmat.score.txt.gz
PROCESS /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/Hispanic/geno_qced.Hispanic.Hispanic.pca.projected.gmmat.score.txt.gz
PROCESS /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/African/geno_qced.African.African.pca.projected.gmmat.score.txt.gz

OUTFILE /mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/metal/AD.GMMAT_APOE4_META .TXT
ANALYZE
ANALYZE HETEROGENEITY

# %%
# Reformate the metal result and generat manhattan and qq plots

meta_APOE4 <- read.table('/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/metal/AD.GMMAT_APOE4_META2.TXT', header = T, sep = '\t')
meta_APOE4 <- meta_APOE4 %>% mutate (SNP = MarkerName)
meta_APOE4 <- meta_APOE4 %>% mutate(across('MarkerName', str_replace_all, '_', ':'))
meta_APOE4 <- meta_APOE4 %>% separate(MarkerName, c('CHR','POS','REF', 'ALT'),  sep = ':')
meta_APOE4 <- meta_APOE4 %>% mutate(across('CHR', str_replace, 'chr', ''))
meta_APOE4$POS <-  as.numeric(meta_APOE4$POS)
meta_APOE4$CHR <-  as.numeric(meta_APOE4$CHR)
write.table(meta_APOE4,'/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/metal/meta.APOE4.txt', sep = '\t', quote = F, col.names = T, row.names = F)

# %%
### For Manhattan plot using qqman #### 
## manhattan plot
png(filename = "/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/metal/meta_apoe4_manhattan.plot.png", width = 6, height = 4, unit='in', res=300)
manhattan(meta_APOE4, chr='CHR', bp='POS', snp='SNP', p='P.value', main = 'Manhattan plot', cex = 0.6, cex.axis = 0.9, col = c("blue4", "orange3"))
dev.off()
### qq plot
png(filename = "/mnt/mfs/statgen/alzheimers-family/AD_common_variants/gmmat/results2/APOE4/metal/meta_apoe4_qq.plot.png", width = 5, height = 5, unit='in', res=300)
qq(meta_APOE4$P.value, main = "QQ plot ", cex = 1.5,las = 1, cex.axis = 0.9, col = "blue4")
dev.off()
# Out:
# png
#   2
# png
#   2

# %%
# calculate lamda

lambda <- median(qchisq(meta_APOE4$P.value, df=1, lower.tail=FALSE)) / qchisq(0.5, 1)

# %%
lambda
# Out:
# [1] 0.9888482

# %% [markdown]
# # Annotation of significant variants

# %%
# import annotation file by Badri (subset of relevant columns only)

annotation <- read.table('~/project_bst/AD_family_design/control_replacement/annotation_from_Badri.txt', header = T)

# list of significant variants

variants <- read.csv("significant_variants_list_AD_family.csv")
